# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
from src.data.pipeline import DataPipeline

# %%
pipeline = DataPipeline()

clean_df = pipeline.run()
# Out:
# Dataset Loaded Successfully
# Shape: (1067371, 8)
# ============================================================
# DATA VALIDATION REPORT
# ============================================================
# ✓ Required Columns : PASSED
#
# Missing Values
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64
#
# Duplicate Rows : 34335
#
# Negative Quantity : 22950
# Negative Price    : 5
#
# Data Types
# Invoice         object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# Price          float64
# Customer ID    float64
# Country         object
# dtype: object
# ============================================================
# Validation Completed
# ============================================================
#
#
# ============================================================
# STARTING DATA CLEANING
# ============================================================
#
# Duplicate Rows Found : 34,335
# Duplicate Rows Removed
#
# InvoiceDate converted to datetime.
# c:\Users\bhard\Intelligent Customer Analytics Platform\src\data\cleaner.py:88: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[DATE_COLUMN] = pd.to_datetime(df[DATE_COLUMN])
# Removed Missing Description : 4,275
# Removed Missing Customer ID : 230,876
# Removed Invalid Price Rows : 70
#
# Cancelled Transactions : 18,390
# Created TotalAmount Column.
#
# Cleaning Completed Successfully.
# ============================================================
#
# Cleaned dataset saved successfully.
# C:\Users\bhard\Intelligent Customer Analytics Platform\data\processed\cleaned_online_retail.csv
#
#
# ============================================================
# CLEANING SUMMARY
# ============================================================
# Original Rows       : 1,067,371
# Final Rows          : 797,815
# Rows Removed        : 269,556
# ============================================================

# %%
clean_df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  IsCancelled  \
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom        False
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom        False
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom        False
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom        False
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom        False
#
#    TotalAmount
# 0         83.4
# 1         81.0
# 2         81.0
# 3        100.8
# 4         30.0

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 797815 entries, 0 to 797814
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      797815 non-null  object
#  1   StockCode    797815 non-null  object
#  2   Description  797815 non-null  object
#  3   Quantity     797815 non-null  int64
#  4   InvoiceDate  797815 non-null  datetime64[ns]
#  5   Price        797815 non-null  float64
#  6   Customer ID  797815 non-null  float64
#  7   Country      797815 non-null  object
#  8   IsCancelled  797815 non-null  bool
#  9   TotalAmount  797815 non-null  float64
# dtypes: bool(1), datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 55.5+ MB

# %%
clean_df.describe(include="all")
# Out:
#        Invoice StockCode                         Description       Quantity  \
# count   797815    797815                              797815  797815.000000
# unique   44870      4646                                5299            NaN
# top     576339    85123A  WHITE HANGING HEART T-LIGHT HOLDER            NaN
# freq       542      5156                                5149            NaN
# mean       NaN       NaN                                 NaN      12.585594
# min        NaN       NaN                                 NaN  -80995.000000
# 25%        NaN       NaN                                 NaN       2.000000
# 50%        NaN       NaN                                 NaN       5.000000
# 75%        NaN       NaN                                 NaN      12.000000
# max        NaN       NaN                                 NaN   80995.000000
# std        NaN       NaN                                 NaN     191.163061
#
#                           InvoiceDate          Price    Customer ID  \
# count                          797815  797815.000000  797815.000000
# unique                            NaN            NaN            NaN
# top                               NaN            NaN            NaN
# freq                              NaN            NaN            NaN
# mean    2011-01-02 13:15:39.345813504       3.703057   15313.157440
# min               2009-12-01 07:45:00       0.001000   12346.000000
# 25%               2010-07-02 09:47:00       1.250000   13964.000000
# 50%               2010-12-02 12:33:00       1.950000   15228.000000
# 75%               2011-07-31 15:50:00       3.750000   16789.000000
# max               2011-12-09 12:50:00   38970.000000   18287.000000
# std                               NaN      71.395672    1696.437628
#
#                Country IsCancelled    TotalAmount
# count           797815      797815  797815.000000
# unique              41           2            NaN
# top     United Kingdom       False            NaN
# freq            716069      779425            NaN
# mean               NaN         NaN      20.418256
# min                NaN         NaN -168469.600000
# 25%                NaN         NaN       4.350000
# 50%                NaN         NaN      11.700000
# 75%                NaN         NaN      19.500000
# max                NaN         NaN  168469.600000
# std                NaN         NaN     313.532519
